# %% [markdown]
# # GeoInfluence of Governors
#
# by [Talha Oz](http://twitter.com/tozCSS) & Manqi Li
#
# This notebook is a demo (also can be considered as a verification step) on one of the states, namely North Dakota (before scaling to all 50 states)

# %%
cd ../
# Out:
# C:\Users\Talha\Documents\WinPython3\projects\GeoInfluence

# %%
import pandas as pd
import json
from mykeys import tw
import twitter
from utilities.geocoder import Geocoder
from collections import Counter

# %%
def oauth_login():
    """Twitter authorization """
    auth = twitter.oauth.OAuth(tw['OAUTH_TOKEN'], tw['OAUTH_TOKEN_SECRET'], tw['CONSUMER_KEY'], tw['CONSUMER_SECRET'])
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

# %%
# read the IDs of the followers of the governor of North Dakota
# this file is generated by dd-css.com
filename = '5522fdf6bd90594f049c4aef.json'
followers_file = open('data/'+filename)
followers = json.load(followers_file)
print(followers.keys())
# Out:
# dict_keys(['parameters', 'username', 'created_time', 'qname', 'data'])

# %%
followers['parameters']['screen_name']
# Out:
# 'NDGovDalrymple'

# %%
fids = followers['data']['followers']

# %%
twitter_api = oauth_login()

# %%
# https://dev.twitter.com/rest/reference/get/users/lookup
resp = []
for i in range(1+len(fids)//100):
    resp.extend(twitter_api.users.lookup(user_id=fids[100*i:100*(i+1)]))

# %%
i = 0
locations = []
for r in resp:
    if r['location'] != '':
        locations.append(r['location'])
        print(r['location'],end='; ')
        i=i+1
i
# Out:
# North Dakota; North Dakota; USA; San Francisco; US; Bismarck, N.D.; Haddonfield, NJ; Fargo, ND; Wherever videos are sold; Walhalla ND; Arizona, USA; Minneapolis, Minnesota; Bismarck, ND; #Fargo #ND; CALIFORNIA AND OREGON; San Francisco, CA; the 'burbs of nyc & philly ; New Salem, ND; Jamestown, North Dakota; 1600 Pennsylvania Ave NW, D.C.; New Milford, CT; Fargo,ND & farm in MN; Bristol, RI; United States; St. Paul or Washington D.C.; West Fargo, ND; Fargo, ND; Pierre, SD; Bismarck, ND; North Dakota; Alexandria, VA; Minneapolis, MN; Washington D.C.; Iowa; Sherwood, ND; Grand Forks, North Dakota, USA; Bismarck, North Dakota; ND, SD, MN; Fargo, North Dakota; Minot, ND; Washington, DC; Grand Forks, ND; Fargo, ND; Upper Midwest; ND; Bismarck, ND; Bismarck, ND; Washington, D.C.; Moorhead, MN; Nevada; Minneapolis, MN; North Dakota; Pittsburgh, PA; Washington, DC; Chicago; Williston, ND; Indiana; Mandan; San Francisco Bay Area; Plano, TX; Minneapolis, MN; Dickinson, North Dakota; ND, MN, & SD; Lansford, North Dakota; North Dakota; Denver, CO; Fargo, ND; Phoenix, Arizona; North Dakota; Tallahassee, FL; Dickinson, North Dakota; Minot, North Dakota; Bismarck, N.D.; North Dakota, USA; Red River Valley; Mandan; West Fargo, ND; Bismarck, ND; Fargo,
# 267

# %%
print('Rate of non-empty user-profile location fields: {0:.2f} %'.format(i*100/len(resp)))
# Out:
# Rate of non-empty user-profile location fields: 69.17 %

# %%
governor = {'name':followers['parameters']['screen_name'], 'fol_locs':locations}
with open('data/loc_'+filename, 'w') as outfile:
    json.dump(governor, outfile)

# %%
# Note: ~4% have more precise location info in their last tweets, we don't use this field at all...
i = 0
for r in resp:
    try:
        if r['status']['place'] is not None:
            print(r['status']['place'])
            i=i+1
    except:
        pass
print('Note: {0:.2f} % have more precise location info in their last tweets, we don\'t use this field at all...'.format(i*100/len(resp)))
# Out:
# {'url': 'https://api.twitter.com/1.1/geo/id/5c8fea63bc3faa5b.json', 'id': '5c8fea63bc3faa5b', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'Fargo', 'bounding_box': {'coordinates': [[[-96.903853, 46.787881], [-96.756332, 46.787881], [-96.756332, 46.941884], [-96.903853, 46.941884]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Fargo, ND', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/01a9a39529b27f36.json', 'id': '01a9a39529b27f36', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'Manhattan', 'bounding_box': {'coordinates': [[[-74.026675, 40.683935], [-73.910408, 40.683935], [-73.910408, 40.877483], [-74.026675, 40.877483]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Manhattan, NY', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/7d893ca2441b0c21.json', 'id': '7d893ca2441b0c21', 'attributes': {}, 'place_type': 'admin', 'contained_within': [], 'name': 'North Dakota', 'bounding_box': {'coordinates': [[[-104.048915, 45.935021], [-96.554508, 45.935021], [-96.554508, 49.000693], [-104.048915, 49.000693]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'North Dakota, USA', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/5a110d312052166f.json', 'id': '5a110d312052166f', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'San Francisco', 'bounding_box': {'coordinates': [[[-122.514926, 37.708075], [-122.357031, 37.708075], [-122.357031, 37.833238], [-122.514926, 37.833238]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'San Francisco, CA', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/5c62ffb0f0f3479d.json', 'id': '5c62ffb0f0f3479d', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'Phoenix', 'bounding_box': {'coordinates': [[[-112.3239143, 33.29026], [-111.9254391, 33.29026], [-111.9254391, 33.8154652], [-112.3239143, 33.8154652]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Phoenix, AZ', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/34b3fd2e17b34d78.json', 'id': '34b3fd2e17b34d78', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'West Fargo', 'bounding_box': {'coordinates': [[[-96.937345, 46.8039405], [-96.8616573, 46.8039405], [-96.8616573, 46.897372], [-96.937345, 46.897372]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'West Fargo, ND', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/c833fbabba6fe48e.json', 'id': 'c833fbabba6fe48e', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'Princeton', 'bounding_box': {'coordinates': [[[-74.710297, 40.3250713], [-74.6197593, 40.3250713], [-74.6197593, 40.3743499], [-74.710297, 40.3743499]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Princeton, NJ', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/7d893ca2441b0c21.json', 'id': '7d893ca2441b0c21', 'attributes': {}, 'place_type': 'admin', 'contained_within': [], 'name': 'North Dakota', 'bounding_box': {'coordinates': [[[-104.048915, 45.935021], [-96.554508, 45.935021], [-96.554508, 49.000693], [-104.048915, 49.000693]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'North Dakota, USA', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/35a6dd7f550504c4.json', 'id': '35a6dd7f550504c4', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'Ruston', 'bounding_box': {'coordinates': [[[-92.695547, 32.496312], [-92.572122, 32.496312], [-92.572122, 32.577488], [-92.695547, 32.577488]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Ruston, LA', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/7d893ca2441b0c21.json', 'id': '7d893ca2441b0c21', 'attributes': {}, 'place_type': 'admin', 'contained_within': [], 'name': 'North Dakota', 'bounding_box': {'coordinates': [[[-104.048915, 45.935021], [-96.554508, 45.935021], [-96.554508, 49.000693], [-104.048915, 49.000693]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'North Dakota, USA', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/d2ddff69682ae534.json', 'id': 'd2ddff69682ae534', 'attributes': {}, 'place_type': 'admin', 'contained_within': [], 'name': 'Montana', 'bounding_box': {'coordinates': [[[-116.050004, 44.35821], [-104.039563, 44.35821], [-104.039563, 49.00139], [-116.050004, 49.00139]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Montana, USA', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/7d893ca2441b0c21.json', 'id': '7d893ca2441b0c21', 'attributes': {}, 'place_type': 'admin', 'contained_within': [], 'name': 'North Dakota', 'bounding_box': {'coordinates': [[[-104.048915, 45.935021], [-96.554508, 45.935021], [-96.554508, 49.000693], [-104.048915, 49.000693]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'North Dakota, USA', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/e06ed4324b139bf2.json', 'id': 'e06ed4324b139bf2', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'Cedar Rapids', 'bounding_box': {'coordinates': [[[-91.7745785, 41.886245], [-91.59113, 41.886245], [-91.59113, 42.0668109], [-91.7745785, 42.0668109]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Cedar Rapids, IA', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/3cd12646c811c87e.json', 'id': '3cd12646c811c87e', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'Bismarck', 'bounding_box': {'coordinates': [[[-100.839587, 46.756481], [-100.68871, 46.756481], [-100.68871, 46.9033258], [-100.839587, 46.9033258]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Bismarck, ND', 'country_code': 'US'}
# {'url': 'https://api.twitter.com/1.1/geo/id/da0b409f35f780db.json', 'id': 'da0b409f35f780db', 'attributes': {}, 'place_type': 'city', 'contained_within': [], 'name': 'Grand Forks', 'bounding_box': {'coordinates': [[[-97.131525, 47.86007], [-96.999601, 47.86007], [-96.999601, 47.954924], [-97.131525, 47.954924]]], 'type': 'Polygon'}, 'country': 'United States', 'full_name': 'Grand Forks, ND', 'country_code': 'US'}
# Note: 3.89 % have more precise location info in their last tweets, we don't use this field at all...

# %%
filename = 'loc_5522fdf6bd90594f049c4aef.json'
followers_file = open('data/'+filename)
followers = json.load(followers_file)
followers.keys()
# Out:
# dict_keys(['name', 'fol_locs'])

# %%
gc = Geocoder('utilities/geodata/state_abbr_file', 'utilities/geodata/city_file')

# %%
latlon = []
for f in followers['fol_locs']:
    point = gc.geocode(f.strip())
    if point != None:
        latlon.append((point[0], point[1]))
cnt = Counter(latlon)
cnt.most_common()
# Out:
# [(('46.813343', '-100.779004'), 33),
#  (('46.871414', '-96.808658'), 19),
#  (('38.913611', '-77.013222'), 13),
#  (('44.964465', '-93.268198'), 5),
#  (('48.233190', '-101.292229'), 3),
#  (('46.864563', '-96.758707'), 3),
#  (('44.367966', '-100.336378'), 2),
#  (('48.156477', '-103.628064'), 2),
#  (('38.880344', '-77.108260'), 2),
#  (('46.883575', '-102.788811'), 2),
#  (('46.828893', '-100.891138'), 2),
#  (('31.056125', '-95.129322'), 1),
#  (('46.595805', '-112.027031'), 1),
#  (('48.795416', '-97.623259'), 1),
#  (('33.050374', '-96.745935'), 1),
#  (('39.726287', '-104.965486'), 1),
#  (('30.451800', '-84.272770'), 1),
#  (('40.123496', '-82.921432'), 1),
#  (('42.516564', '-89.029964'), 1),
#  (('38.816242', '-77.071282'), 1),
#  (('40.441419', '-79.977292'), 1),
#  (('48.961469', '-101.631889'), 1),
#  (('41.684200', '-71.268669'), 1),
#  (('46.780373', '-92.117079'), 1),
#  (('33.590709', '-111.895985'), 1),
#  (('35.357276', '-119.031661'), 1),
#  (('47.673341', '-117.410271'), 1),
#  (('40.352206', '-74.657071'), 1),
#  (('33.528370', '-112.076300'), 1),
#  (('39.896280', '-75.035908'), 1),
#  (('46.333108', '-113.296564'), 1),
#  (('47.268088', '-101.777229'), 1),
#  (('44.410322', '-103.518486'), 1)]

# %%
from IPython.display import HTML
HTML('<iframe width="1000" height="600" scrolling="no" frameborder="no" src="https://www.google.com/fusiontables/embedviz?q=select+col0+from+1mGLpmSCTW6wK07tL0xkd-nmvY7uLJzsl4hd0sRHD+limit+1000&amp;viz=HEATMAP&amp;h=true&amp;lat=40.33704203649286&amp;lng=-95.15016500000002&amp;t=1&amp;z=5&amp;l=col0&amp;y=2&amp;tmplt=2&amp;hmd=true&amp;hmg=%2366ff0000%2C%2393ff00ff%2C%23c1ff00ff%2C%23eeff00ff%2C%23f4e300ff%2C%23f4e300ff%2C%23f9c600ff%2C%23ffaa00ff%2C%23ff7100ff%2C%23ff3900ff%2C%23ff0000ff&amp;hmo=0.6&amp;hmr=25&amp;hmw=0&amp;hml=ONE_COL_LAT_LNG"></iframe>')
# Out:
# <iframe width="1000" height="600" scrolling="no" frameborder="no" src="https://www.google.com/fusiontables/embedviz?q=select+col0+from+1mGLpmSCTW6wK07tL0xkd-nmvY7uLJzsl4hd0sRHD+limit+1000&amp;viz=HEATMAP&amp;h=true&amp;lat=40.33704203649286&amp;lng=-95.15016500000002&amp;t=1&amp;z=5&amp;l=col0&amp;y=2&amp;tmplt=2&amp;hmd=true&amp;hmg=%2366ff0000%2C%2393ff00ff%2C%23c1ff00ff%2C%23eeff00ff%2C%23f4e300ff%2C%23f4e300ff%2C%23f9c600ff%2C%23ffaa00ff%2C%23ff7100ff%2C%23ff3900ff%2C%23ff0000ff&amp;hmo=0.6&amp;hmr=25&amp;hmw=0&amp;hml=ONE_COL_LAT_LNG"></iframe>
